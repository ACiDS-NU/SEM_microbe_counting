# %%
import pandas as pd
#import xlrd #do not need to explicitly import, but needed for pandas.read_excel
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import mahotas
import cv2
import os
import h5py

# %%
data_dir = './7Feb2019_DeMMOcartridgesFebNovAug17'
label_file = (data_dir + '/DeMMO_Biofilm_CellCounts.xlsx')
data_labels = pd.read_excel(label_file).dropna()
#int(data_labels["cells.counted"][0]) # test count
data_labels
# Out:
#        Site      Tube Date Deployed Date Collected       Mineral Experiment  \
# 0   DeMMO 1   7 Large    2017-08-31     2018-04-18       calcite    mineral
# 1   DeMMO 1   7 Large    2017-08-31     2018-04-18       calcite    mineral
# 2   DeMMO 1   7 Large    2017-08-31     2018-04-18       calcite    control
# 3   DeMMO 1   9 Large    2017-08-31     2018-04-18     muscovite    mineral
# 4   DeMMO 1   9 Large    2017-08-31     2018-04-18     muscovite    mineral
# 5   DeMMO 1   9 Large    2017-08-31     2018-04-18     muscovite    control
# 6   DeMMO 1  12 Large    2017-08-31     2018-04-18  control sand    Control
# 8   DeMMO 1      SC 1    2017-08-31     2018-04-18    pyrolusite    mineral
# 9   DeMMO 1      SC 1    2017-08-31     2018-04-18    pyrolusite    control
# 10  DeMMO 1      SC 2    2017-08-31     2018-04-18      siderite    mineral
# 11  DeMMO 1      SC 2    2017-08-31     2018-04-18      siderite    control
# 12  DeMMO 1      SC 3    2017-08-31     2018-04-18        pyrite    mineral
# 13  DeMMO 1      SC 3    2017-08-31     2018-04-18        pyrite    control
# 14  DeMMO 1      SC 4    2017-08-31     2018-04-18      hematite    mineral
# 15  DeMMO 1      SC 4    2017-08-31     2018-04-18      hematite    control
# 16  DeMMO 1      SC 5    2017-08-31     2018-04-18     magnetite    mineral
# 17  DeMMO 1      SC 5    2017-08-31     2018-04-18     magnetite    control
# 18  DeMMO 1     SC 10    2017-08-31     2018-04-18  control sand    Control
# 19  DeMMO 1     SC 10    2017-08-31     2018-04-18  control sand    control
# 20  DeMMO 1         A    2017-11-30     2018-04-18    Pyrolusite    mineral
# 21  DeMMO 1         A    2017-11-30     2018-04-18    pyrolusite    control
# 22  DeMMO 1         C    2017-11-30     2018-04-18        Pyrite    mineral
# 23  DeMMO 1         C    2017-11-30     2018-04-18        pyrite    control
# 24  DeMMO 1         D    2017-11-30     2018-04-18      Hematite    mineral
# 25  DeMMO 1         D    2017-11-30     2018-04-18      hematite    control
# 26  DeMMO 1         E    2017-11-30     2018-04-18     Magnetite    mineral
# 27  DeMMO 1         E    2017-11-30     2018-04-18     magnetite    control
# 28  DeMMO 1         F    2017-11-30     2018-04-18          sand    Control
# 29  DeMMO 1         F    2017-11-30     2018-04-18          sand    control
# 30  Demmo 3         7    2017-02-15     2017-05-11    Pyrolusite    mineral
# ..      ...       ...           ...            ...           ...        ...
# 46  Demmo 3        12    2017-02-15     2017-05-11  control sand    control
# 47  DeMMO 3   1 Large    2017-08-30     2018-04-17       calcite    mineral
# 48  DeMMO 3   1 Large    2017-08-30     2018-04-17       calcite    mineral
# 49  DeMMO 3   1 Large    2017-08-30     2018-04-17       calcite    control
# 50  DeMMO 3   3 Large    2017-08-30     2018-04-17     muscovite    mineral
# 51  DeMMO 3   3 Large    2017-08-30     2018-04-17     muscovite    mineral
# 52  DeMMO 3   3 Large    2017-08-30     2018-04-17     muscovite    control
# 54  DeMMO 3   6 Large    2017-08-30     2018-04-17  control sand    control
# 55  DeMMO 3         A    2017-11-27     2018-04-17    pyrolusite    mineral
# 57  DeMMO 3         C    2017-11-27     2018-04-17        pyrite    mineral
# 58  DeMMO 3         C    2017-11-27     2018-04-17        pyrite    control
# 59  DeMMO 3         D    2017-11-27     2018-04-17      hematite    mineral
# 60  DeMMO 3         D    2017-11-27     2018-04-17      hematite    control
# 61  DeMMO 3         E    2017-11-27     2018-04-17     magnetite    mineral
# 63  DeMMO 3         F    2017-11-27     2018-04-17  control sand    Control
# 64  DeMMO 3         F    2017-11-27     2018-04-17  control sand    control
# 65  Demmo 6         1    2017-02-14     2017-05-10    Pyrolusite    mineral
# 66  Demmo 6         1    2017-02-14     2017-05-10    Pyrolusite    mineral
# 67  Demmo 6         1    2017-02-14     2017-05-10    pyrolusite    control
# 68  Demmo 6         2    2017-02-14     2017-05-10      Siderite    mineral
# 69  Demmo 6         2    2017-02-14     2017-05-10      Siderite    mineral
# 70  Demmo 6         2    2017-02-14     2017-05-10      siderite    control
# 71  Demmo 6         3    2017-02-14     2017-05-10        Pyrite    mineral
# 72  Demmo 6         3    2017-02-14     2017-05-10        Pyrite    mineral
# 74  Demmo 6         4    2017-02-14     2017-05-10      Hematite    mineral
# 75  Demmo 6         4    2017-02-14     2017-05-10      Hematite    mineral
# 77  Demmo 6         5    2017-02-14     2017-05-10     Magnetite    mineral
# 78  Demmo 6         5    2017-02-14     2017-05-10     Magnetite    mineral
# 80  DeMMO 6         6    2017-02-14     2017-05-10  control sand    Control
# 81  DeMMO 6         6    2017-02-14     2017-05-10  control sand    control
#
#                 Type  Duration.days  Cell.density.sq.mm  cells.counted
# 0                Exp            231          447.065598          29.00
# 1                Rep            231         2016.095890         192.00
# 2   Internal Control            231          875.396810          81.00
# 3                Exp            231         6939.881357         449.00
# 4                Rep            231         5523.557849         298.00
# 5   Internal Control            231          937.544592          75.00
# 6            Control            231        48192.761850        1559.00
# 8                exp            231        52349.678599        4155.00
# 9   Internal Control            231        21472.987787        1684.00
# 10               Exp            231        10737.033003         472.00
# 11  Internal Control            231         9975.474458         760.00
# 12               exp            231         3649.210184         323.00
# 13  Internal Control            231        12075.574344         828.00
# 14               exp            231        16096.481572        1440.00
# 15  Internal Control            231         9141.016013         839.00
# 16               exp            231         3220.357189         283.00
# 17  Internal Control            231        67669.885211        2320.00
# 18           Control            231        23292.016916        1952.00
# 19       Control Rep            231        69828.321204        2660.00
# 20               Exp            201         3237.371575         210.00
# 21  Internal Control            201         1920.727219         128.00
# 22               Exp            201        10082.100049         327.00
# 23  Internal Control            201         1978.151447         151.00
# 24               Exp            201         1125.372024          73.00
# 25  Internal Control            201         5814.276475         284.00
# 26               Exp            201          940.379362          61.00
# 27  Internal Control            201         2514.593284         182.00
# 28           Control            201         2675.127236         214.00
# 29       control rep            201        17434.713075         564.00
# 30               Exp             85         9804.611057         318.00
# ..               ...            ...                 ...            ...
# 46       Control Rep             85         1360.154921          88.00
# 47               Exp            231         2040.232381         132.00
# 48               Rep            231         1364.518918          97.00
# 49  Internal Control            231         1514.717980          98.00
# 50               Exp            231         3446.756220         223.00
# 51               Rep            231         3622.772953         235.00
# 52  Internal Control            231          868.497190          59.00
# 54       Control Rep            231         1112.854026          72.00
# 55               exp            199         4008.413685         894.00
# 57               exp            199         2313.269941         108.00
# 58  Internal Control            199          940.379362          61.00
# 59               exp            199         4131.502772         268.00
# 60  Internal Control            199         2859.416595         185.00
# 61               exp            199         4652.348081         301.00
# 63           Control            199         7388.114228         478.00
# 64       Control Rep            199         2127.415748         132.00
# 65               Exp             85        20811.674413         675.00
# 66               Rep             85        47882.267205        1553.00
# 67  internal Control             85         1165.993061           3.85
# 68               Exp             85         1834.510559         119.00
# 69               Rep             85        10881.239366         352.00
# 70  internal Control             85           15.416055           1.00
# 71               Exp             85        10452.085372         678.00
# 72               Rep             85        27656.402886         897.00
# 74               Exp             85        18314.273483         594.00
# 75               Rep             85         5565.195899         361.00
# 77               Exp             85        12517.836758         406.00
# 78               Rep             85         4439.823875         288.00
# 80           Control             85          355.495036          23.00
# 81       Control Rep             85         5133.546355         333.00
#
# [73 rows x 10 columns]

# %%
fixed_size = tuple((768, 551)) #these are the lowest dimensions I found; D1T12Large_glass_Aug2017.tif
#os.listdir(data_dir)
bins = 10

# %%
# feature-descriptor-1: Hu Moments
def fd_hu_moments(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    feature = cv2.HuMoments(cv2.moments(image)).flatten()
    return feature


# feature-descriptor-2: Haralick Texture
def fd_haralick(image):
    # convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # compute the haralick texture feature vector
    haralick = mahotas.features.haralick(gray).mean(axis=0)
    # return the result
    return haralick


# Color Histogram -- Maybe not helpful?
def fd_histogram(image, mask = None):
    # convert the image to HSV color-space
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # compute the color histogram
    hist  = cv2.calcHist([image], [0, 1, 2], None, [bins, bins, bins], [0, 256, 0, 256, 0, 256])
    # normalize the histogram
    cv2.normalize(hist, hist)
    # return the histogram
    return hist.flatten()

# %%
global_features = []
labels = []
data_list = os.listdir(data_dir)[:-1] #cuts last file assuming it is excel table
for i in data_labels.index:
    file = data_dir + '/' + data_list[i]
    current_label = int(data_labels["cells.counted"][i])
    image = cv2.imread(file)
    image = cv2.resize(image, fixed_size)
    fv_hu_moments = fd_hu_moments(image)
    fv_haralick = fd_haralick(image)
    fv_histogram  = fd_histogram(image)
    global_feature = np.hstack([fv_histogram, fv_haralick, fv_hu_moments])
    labels.append(current_label)
    global_features.append(global_feature)

# %%
target = labels
scaler = MinMaxScaler(feature_range=(0, 1))
rescaled_features = scaler.fit_transform(global_features)
h5f_data = h5py.File('data.h5', 'w')
h5f_data.create_dataset('dataset_1', data=np.array(rescaled_features))
h5f_label = h5py.File('labels.h5', 'w')
h5f_label.create_dataset('dataset_1', data=np.array(target))
h5f_data.close()
h5f_label.close()
